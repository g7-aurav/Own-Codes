# %%
import numpy as np
import pandas as pd

# %%
S_Date1 = '2026-05-05 00:00:00'
E_Date1 = '2026-05-11 23:59:59'

#For Autoapproved jobs
S_Date2 = '2026-05-06 00:00:00'
E_Date2 = '2026-05-12 23:59:59'

Raw_data_path = r"C:\Gaurav\US Reconcillation\2026\May'26\5 May'26 - 11 May'26\Raw\Closed_Case_–_Activity_Invoices_–_Activity (5).xlsx"
WD_Files_path = r"C:\Gaurav\US Reconcillation\2026\May'26\5 May'26 - 11 May'26\Combine\Combine_Final_25.xlsx"
Prev_WD_Files_path = r"C:\Gaurav\US Reconcillation\2026\April'26\28 April - 4 May\Working\US Working 28 April'26 - 4 May'26 (Run 06 April'26 - 07 May'26 ).xlsx"
Output_path = r"C:\\Gaurav\\US Reconcillation\\2026\\May'26\\5 May'26 - 11 May'26\\Upload\\Final_Detailed.xlsx"

# %%
raw_data = pd.read_excel(Raw_data_path)
raw_data
# Out:
#      Activity Invoice Report              Unnamed: 1          Unnamed: 2  \
# 0                        NaN                     NaN                 NaN
# 1                Provider ID           Provider Name     Employment Type
# 2                  184004394           Tante Brianna                 NaN
# 3                  184002562        Canning Katelyn                  NaN
# 4                  184001209           Exyt Latasha                  NaN
# ...                      ...                     ...                 ...
# 9317               184001227         Smith  Shilain   Employee Full-Time
# 9318                   26645             Wheeler Kim  Employee Full-Time
# 9319               184000364  Anderson-White Deirdre  Employee Part-Time
# 9320               184001008         Choudry Faryal   Employee Full-Time
# 9321               184000499           Waples Kimmy                  NaN
#
#        Unnamed: 3 Unnamed: 4                  Unnamed: 5  \
# ...

# %%
data1 = raw_data.copy()
data1
# Out:
#      Activity Invoice Report              Unnamed: 1          Unnamed: 2  \
# 0                        NaN                     NaN                 NaN
# 1                Provider ID           Provider Name     Employment Type
# 2                  184004394           Tante Brianna                 NaN
# 3                  184002562        Canning Katelyn                  NaN
# 4                  184001209           Exyt Latasha                  NaN
# ...                      ...                     ...                 ...
# 9317               184001227         Smith  Shilain   Employee Full-Time
# 9318                   26645             Wheeler Kim  Employee Full-Time
# 9319               184000364  Anderson-White Deirdre  Employee Part-Time
# 9320               184001008         Choudry Faryal   Employee Full-Time
# 9321               184000499           Waples Kimmy                  NaN
#
#        Unnamed: 3 Unnamed: 4                  Unnamed: 5  \
# ...

# %%
data1 = data1.drop(data1.index[:1])
data1 = data1.reset_index(drop=True)
data1.head()
# Out:
#   Activity Invoice Report        Unnamed: 1       Unnamed: 2   Unnamed: 3  \
# 0             Provider ID     Provider Name  Employment Type  Supplier ID
# 1               184004394     Tante Brianna              NaN          NaN
# 2               184002562  Canning Katelyn               NaN          NaN
# 3               184001209     Exyt Latasha               NaN          NaN
# 4               184004392     Redman Althea              NaN          NaN
#
#   Unnamed: 4                  Unnamed: 5                Unnamed: 6  \
# 0  Vendor ID  Pay Vendor Directly (Y/N)?          Provider Country
# 1          1                          No  UNITED STATES OF AMERICA
# 2          1                          No  UNITED STATES OF AMERICA
# 3          1                          No  UNITED STATES OF AMERICA
# 4          1                          No  UNITED STATES OF AMERICA
#
#                  Unnamed: 7 Unnamed: 8                            Unnamed: 9  \
# ...

# %%
data1.columns = data1.iloc[0]

# %%
data1.head()
# Out:
# 0  Provider ID     Provider Name  Employment Type  Supplier ID  Vendor ID  \
# 0  Provider ID     Provider Name  Employment Type  Supplier ID  Vendor ID
# 1    184004394     Tante Brianna              NaN          NaN          1
# 2    184002562  Canning Katelyn               NaN          NaN          1
# 3    184001209     Exyt Latasha               NaN          NaN          1
# 4    184004392     Redman Althea              NaN          NaN          1
#
# 0  Pay Vendor Directly (Y/N)?          Provider Country  \
# 0  Pay Vendor Directly (Y/N)?          Provider Country
# 1                          No  UNITED STATES OF AMERICA
# 2                          No  UNITED STATES OF AMERICA
# 3                          No  UNITED STATES OF AMERICA
# 4                          No  UNITED STATES OF AMERICA
#
# 0  Provider  Province/State     Org ID                              Org Name  \
# 0  Provider  Province/State     Org ID                              Org Name
# ...

# %%
data1 = data1.drop(data1.index[0])
data1.head()
# Out:
# 0 Provider ID     Provider Name Employment Type Supplier ID Vendor ID  \
# 1   184004394     Tante Brianna             NaN         NaN         1
# 2   184002562  Canning Katelyn              NaN         NaN         1
# 3   184001209     Exyt Latasha              NaN         NaN         1
# 4   184004392     Redman Althea             NaN         NaN         1
# 5   184004392     Redman Althea             NaN         NaN         1
#
# 0 Pay Vendor Directly (Y/N)?          Provider Country  \
# 1                         No  UNITED STATES OF AMERICA
# 2                         No  UNITED STATES OF AMERICA
# 3                         No  UNITED STATES OF AMERICA
# 4                         No  UNITED STATES OF AMERICA
# 5                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                              Org Name  \
# 1                    TEXAS    1139349   Arizona State University - Student
# ...

# %%
data1 = data1.reset_index(drop=True)
data1.head()
# Out:
# 0 Provider ID     Provider Name Employment Type Supplier ID Vendor ID  \
# 0   184004394     Tante Brianna             NaN         NaN         1
# 1   184002562  Canning Katelyn              NaN         NaN         1
# 2   184001209     Exyt Latasha              NaN         NaN         1
# 3   184004392     Redman Althea             NaN         NaN         1
# 4   184004392     Redman Althea             NaN         NaN         1
#
# 0 Pay Vendor Directly (Y/N)?          Provider Country  \
# 0                         No  UNITED STATES OF AMERICA
# 1                         No  UNITED STATES OF AMERICA
# 2                         No  UNITED STATES OF AMERICA
# 3                         No  UNITED STATES OF AMERICA
# 4                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                              Org Name  \
# 0                    TEXAS    1139349   Arizona State University - Student
# ...

# %%
filtered_data1 = data1[data1['Vendor ID'] != 1]
filtered_data1.head()
# Out:
# 0  Provider ID   Provider Name                   Employment Type Supplier ID  \
# 16       13168    Hecht Marion  Contractor (Affiliated Provider)      230865
# 19         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 22         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 25         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 31       11830  Babbitt Claire  Contractor (Affiliated Provider)      234357
#
# 0  Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 16      1758                        Yes  UNITED STATES OF AMERICA
# 19       NaN                         No  UNITED STATES OF AMERICA
# 22       NaN                         No  UNITED STATES OF AMERICA
# 25       NaN                         No  UNITED STATES OF AMERICA
# 31       NaN                         No  UNITED STATES OF AMERICA
#
# 0  Provider  Province/State     Org ID  \
# 16               NEW JERSEY  184053749
# ...

# %%
filtered_data1.head()
# Out:
# 0  Provider ID   Provider Name                   Employment Type Supplier ID  \
# 16       13168    Hecht Marion  Contractor (Affiliated Provider)      230865
# 19         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 22         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 25         467       Vyzas Ben  Contractor (Affiliated Provider)       34348
# 31       11830  Babbitt Claire  Contractor (Affiliated Provider)      234357
#
# 0  Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 16      1758                        Yes  UNITED STATES OF AMERICA
# 19       NaN                         No  UNITED STATES OF AMERICA
# 22       NaN                         No  UNITED STATES OF AMERICA
# 25       NaN                         No  UNITED STATES OF AMERICA
# 31       NaN                         No  UNITED STATES OF AMERICA
#
# 0  Provider  Province/State     Org ID  \
# 16               NEW JERSEY  184053749
# ...

# %%
filtered_data1 = filtered_data1.reset_index(drop=True)
filtered_data1
# Out:
# 0   Provider ID    Provider Name                   Employment Type  \
# 0         13168     Hecht Marion  Contractor (Affiliated Provider)
# 1           467        Vyzas Ben  Contractor (Affiliated Provider)
# 2           467        Vyzas Ben  Contractor (Affiliated Provider)
# 3           467        Vyzas Ben  Contractor (Affiliated Provider)
# 4         11830   Babbitt Claire  Contractor (Affiliated Provider)
# ..          ...              ...                               ...
# 968        4032     Continuum R3  Contractor (Affiliated Provider)
# 969        4032     Continuum R3  Contractor (Affiliated Provider)
# 970        4032     Continuum R3  Contractor (Affiliated Provider)
# 971        8847      Schirg Ralf  Contractor (Affiliated Provider)
# 972       22851  Canepa Patricia  Contractor (Affiliated Provider)
#
# 0   Supplier ID Vendor ID Pay Vendor Directly (Y/N)?  \
# 0        230865      1758                        Yes
# ...

# %%
filtered_data1.shape
# Out:
# (973, 65)

# %%
filtered_data1.columns
# Out:
# Index(['Provider ID', 'Provider Name', 'Employment Type', 'Supplier ID',
#        'Vendor ID', 'Pay Vendor Directly (Y/N)?', 'Provider Country',
#        'Provider  Province/State', 'Org ID', 'Org Name', 'Renewal Date',
#        'Max hours for contract period', 'Provider Email Type', 'Model Number',
#        'Fee Type', 'Case ID', 'Activity ID', 'Activity Opened Date',
#        'Activity Status', 'Service Code', 'Modality', 'Invoice ID',
#        'Invoice Status', 'Invoice Approval Date', 'Approver Name',
#        'Provider Invoice Number', 'Invoice Created Date', 'Created by',
#        'Export Date', 'Regular Rate Fee', 'Regular Rate Type',
#        'Regular Rate Billable \nHours', 'Regular Rate Non-Billable \nHours',
#        'No Show \nFee', 'No Show \nType', 'No Show Billable\nHours',
#        'No Show Non-Billable\nHours', 'Case Management Fee',
#        'Case Management Type', 'Case Management Billble Hours',
#        'Case Management Non-Billble Hours', 'Special Rate Fee',
# ...

# %%
pd.set_option('display.max_columns', None)
filtered_data1.head(2)
# Out:
# 0 Provider ID Provider Name                   Employment Type Supplier ID  \
# 0       13168  Hecht Marion  Contractor (Affiliated Provider)      230865
# 1         467     Vyzas Ben  Contractor (Affiliated Provider)       34348
#
# 0 Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 0      1758                        Yes  UNITED STATES OF AMERICA
# 1       NaN                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID  \
# 0               NEW JERSEY  184053749
# 1                  FLORIDA  184046449
#
# 0                                  Org Name         Renewal Date  \
# 0  Western Governors University Corporation  2025-12-01 00:00:00
# 1                        Citibank, NA - USA  2026-01-01 00:00:00
#
# 0 Max hours for contract period Provider Email Type Model Number  \
# 0                           NaN                 NaN            3
# 1                           NaN                 NaN           13
#
# ...

# %%
filtered_data1['Created by'].unique()
# Out:
# array(['13168', '467', '11830', '495083', 'Kajal Garg', '18417',
#        'Vanshika Sachdeva', '184004513', '184004096', '496766', '21695',
#        '13568', '184000058', '18811', '184001553', '184004512',
#        '184003705', '13523', 'Vilma Papillon', '184002965', '184002830',
#        '184002574', '499959', '26575', '495688', '14709', '184004023',
#        '184002195', '184000538', '497244', '184002825', '13707', '19321',
#        'Kimberly Winters', '184004152', '19507', '499943', '184000053',
#        '184000234', '24232', '13105', '12401', '184003704', '184000884',
#        '184002172', '184004496', '12383', '25416', '13987', '184002895',
#        '18329', '22614', '14624', '15014', '19113', '22366',
#        '184004457  ', '184003857', '184004438', '184004115', '184003969',
#        '494985', '12639', '495326', '22339', '11905', '184002373',
#        '499900', '499851', '12849', '184003985', '184004410',
#        'Sweta Vanker', '13961', '15248', '13703', '184000061',
# ...

# %%
filtered_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 65 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Provider ID                        973 non-null    object
#  1   Provider Name                      973 non-null    object
#  2   Employment Type                    962 non-null    object
#  3   Supplier ID                        951 non-null    object
#  4   Vendor ID                          671 non-null    object
#  5   Pay Vendor Directly (Y/N)?         973 non-null    object
#  6   Provider Country                   973 non-null    object
#  7   Provider  Province/State           973 non-null    object
#  8   Org ID                             973 non-null    object
#  9   Org Name                           973 non-null    object
#  10  Renewal Date                       973 non-null    object
# ...

# %%
filtered_data1['Invoice Created Date'] = pd.to_datetime(filtered_data1['Invoice Created Date'], errors='coerce')
filtered_data1['Invoice Approval Date'] = pd.to_datetime(filtered_data1['Invoice Approval Date'], errors='coerce')

# %%
filtered_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 65 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Provider ID                        973 non-null    object
#  1   Provider Name                      973 non-null    object
#  2   Employment Type                    962 non-null    object
#  3   Supplier ID                        951 non-null    object
#  4   Vendor ID                          671 non-null    object
#  5   Pay Vendor Directly (Y/N)?         973 non-null    object
#  6   Provider Country                   973 non-null    object
#  7   Provider  Province/State           973 non-null    object
#  8   Org ID                             973 non-null    object
#  9   Org Name                           973 non-null    object
#  10  Renewal Date                       973 non-null    object
# ...

# %%
sorted_values = filtered_data1['Created by'].unique()
sorted_values.sort()
print(sorted_values)
# Out:
# [' 184002471' ' 497897' '11784' '11830' '11885' '11905' '12149' '12200'
#  '12211' '12383' '12401' '12453' '12561' '12569' '12639' '12849' '12854'
#  '13105' '13168' '13252' '13340' '13523' '13568' '13570' '13703' '13707'
#  '13776' '13788' '13793' '13861' '13939' '13961' '13987' '14073' '14109'
#  '14134' '14157' '14179' '14280' '14395' '14531' '14600' '14624' '14709'
#  '14777' '14833' '14904' '15014' '15055' '15248' '15424' '15558' '15659'
#  '15847' '15931' '15948' '16419' '16533' '16593' '16748' '16938' '16954'
#  '17776' '18158' '18235' '18329' '18355' '184000053' '184000058'
#  '184000061' '184000074' '184000099' '184000127' '184000228' '184000234'
#  '184000341' '184000538' '184000605' '184000686' '184000707' '184000822'
#  '184000865' '184000873' '184000884' '184000919' '184000977' '184000988'
#  '184001065' '184001095' '184001146' '184001241' '184001553' '184001581'
#  '184001712' '184001834' '184001849' '184001878' '184001921' '184001970'
# ...

# %%
# Find non-integer values
numeric_values = pd.to_numeric(filtered_data1['Created by'], errors='coerce')
non_int_mask = numeric_values.isna() & filtered_data1['Created by'].notna()

# Get rows with non-integer values
non_integer_rows = filtered_data1[non_int_mask]
created_by_names = non_integer_rows['Created by'].unique()

print(created_by_names)
# Out:
# ['Kajal Garg' 'Vanshika Sachdeva' 'Vilma Papillon' 'Kimberly Winters'
#  'Sweta Vanker' 'Darpan Lnu' 'WSPBilling' 'Neha Saini' 'carmstrong'
#  'Ayushi Lnu']

# %%
filter1 = filtered_data1['Created by'].isin(created_by_names)

start_date1 = S_Date1
end_date1 = E_Date1

filter2 = (filtered_data1['Invoice Created Date'] >= start_date1) & (filtered_data1['Invoice Created Date'] <= end_date1)

filtered_data2 = filtered_data1[filter1 & filter2]

filtered_data2.head(2)
# Out:
# 0   Provider ID   Provider Name                   Employment Type Supplier ID  \
# 687      498335  Garnham Steven  Contractor (Affiliated Provider)      419386
# 688      498335  Garnham Steven                               NaN      419386
#
# 0   Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 687       NaN                         No  UNITED STATES OF AMERICA
# 688       NaN                         No  UNITED STATES OF AMERICA
#
# 0   Provider  Province/State     Org ID                           Org Name  \
# 687             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
# 688             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
#
# 0           Renewal Date Max hours for contract period Provider Email Type  \
# 687  2025-10-01 00:00:00                           NaN                 NaN
# 688  2025-10-01 00:00:00                           NaN                 NaN
#
# 0   Model Number                Fee Type    Case ID Activity ID  \
# ...

# %%
# filterx = filtered_data1[filtered_data1['Created by'].isin(['Ayushi Lnu','Darpan Lnu', 'Kajal Garg', 'Neha Saini',
#  'Shivpreet Sandhu', 'Sweta Vanker', 'Vanshika Sachdeva','sweta.vanker','Miriam Charow','mina.navaei'])]

# start_date1 = '2025-10-13 00:00:00'
# end_date1 = '2025-10-20 23:59:59'

# filtery = filterx[(filterx['Invoice Created Date'] >= start_date1) & (filtered_data1['Invoice Created Date'] <= end_date1)]

# filtery.head(1)

# %%
filtered_data2.shape
# Out:
# (101, 65)

# %%
filtered_data1['Approver Name'].unique()
# Out:
# array(['AutoApprovalJob', nan, 'Sweta Vanker', 'Vanshika Sachdeva'],
#       dtype=object)

# %%
distinct_values = filtered_data1['Approver Name'].dropna().unique()


value_to_exclude = 'AutoApprovalJob'
filtered_distinct = distinct_values[distinct_values != value_to_exclude]

print(filtered_distinct)
# Out:
# ['Sweta Vanker' 'Vanshika Sachdeva']

# %%
filter3 = filtered_data1['Approver Name'].isin(filtered_distinct)

start_date2 = S_Date1
end_date2 = E_Date1

filter4 = (filtered_data1['Invoice Approval Date'] >= start_date1) & (filtered_data1['Invoice Approval Date'] <= end_date1)

filtered_data3 = filtered_data1[filter3 & filter4]

filtered_data3.head(2)
# Out:
# 0   Provider ID                   Provider Name  \
# 660       14134              Christie  Gricelda
# 717   184003755  Forbes (ONSITE BLACK) Latasha
#
# 0                     Employment Type Supplier ID  Vendor ID  \
# 660  Contractor (Affiliated Provider)      238562       1635
# 717  Contractor (Affiliated Provider)  SUP-019604  184001797
#
# 0   Pay Vendor Directly (Y/N)?          Provider Country  \
# 660                        Yes  UNITED STATES OF AMERICA
# 717                        Yes  UNITED STATES OF AMERICA
#
# 0   Provider  Province/State     Org ID  \
# 660                    TEXAS  184039418
# 717                 NEW YORK  184050564
#
# 0                                             Org Name         Renewal Date  \
# 660         SWBC Professional Employer Services V, LLC  2025-07-01 00:00:00
# 717  Blackstone Administrative Services Partnership...  2026-01-01 00:00:00
#
# 0   Max hours for contract period Provider Email Type Model Number  \
# ...

# %%
filtered_data3.shape
# Out:
# (10, 65)

# %%
filter5 = filtered_data1['Approver Name'] == 'AutoApprovalJob'

start_date3 = S_Date2
end_date4 = E_Date2

filter6 = (filtered_data1['Invoice Approval Date'] >= start_date3) & (filtered_data1['Invoice Approval Date'] <= end_date4)

filtered_data4 = filtered_data1[filter5 & filter6]

filtered_data4.head(2)
# Out:
# 0   Provider ID       Provider Name                   Employment Type  \
# 659       14134  Christie  Gricelda  Contractor (Affiliated Provider)
# 661       14134  Christie  Gricelda  Contractor (Affiliated Provider)
#
# 0   Supplier ID Vendor ID Pay Vendor Directly (Y/N)?  \
# 659      238562      1635                        Yes
# 661      238562      1635                        Yes
#
# 0            Provider Country Provider  Province/State     Org ID  \
# 659  UNITED STATES OF AMERICA                    TEXAS  184046449
# 661  UNITED STATES OF AMERICA                    TEXAS  184046449
#
# 0              Org Name         Renewal Date Max hours for contract period  \
# 659  Citibank, NA - USA  2026-01-01 00:00:00                           NaN
# 661  Citibank, NA - USA  2026-01-01 00:00:00                           NaN
#
# 0   Provider Email Type Model Number                Fee Type    Case ID  \
# 659                 NaN           13  Per Employee Per Month  184930575
# ...

# %%
filtered_data4.shape
# Out:
# (123, 65)

# %%
combine_filtered = pd.concat([filtered_data2,filtered_data3,filtered_data4],ignore_index = True)
combine_filtered.head(2)
# Out:
# 0 Provider ID   Provider Name                   Employment Type Supplier ID  \
# 0      498335  Garnham Steven  Contractor (Affiliated Provider)      419386
# 1      498335  Garnham Steven                               NaN      419386
#
# 0 Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 0       NaN                         No  UNITED STATES OF AMERICA
# 1       NaN                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                           Org Name  \
# 0             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
# 1             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
#
# 0         Renewal Date Max hours for contract period Provider Email Type  \
# 0  2025-10-01 00:00:00                           NaN                 NaN
# 1  2025-10-01 00:00:00                           NaN                 NaN
#
# 0 Model Number                Fee Type    Case ID Activity ID  \
# ...

# %%
combine_filtered.shape
# Out:
# (234, 65)

# %%
combine_filtered['concat'] = combine_filtered['Activity ID'].astype(str) + '-' + combine_filtered['Invoice ID'].astype(str)
combine_filtered.head(2)
# Out:
# 0 Provider ID   Provider Name                   Employment Type Supplier ID  \
# 0      498335  Garnham Steven  Contractor (Affiliated Provider)      419386
# 1      498335  Garnham Steven                               NaN      419386
#
# 0 Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 0       NaN                         No  UNITED STATES OF AMERICA
# 1       NaN                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                           Org Name  \
# 0             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
# 1             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
#
# 0         Renewal Date Max hours for contract period Provider Email Type  \
# 0  2025-10-01 00:00:00                           NaN                 NaN
# 1  2025-10-01 00:00:00                           NaN                 NaN
#
# 0 Model Number                Fee Type    Case ID Activity ID  \
# ...

# %%
Ap_combine_data = pd.read_excel(WD_Files_path)
Ap_combine_data.head(1)
# Out:
#                                         Batch_Number   Status  \
# 0  Symphoni_PR_Invoice_GBR_2026-05-07.xlsx|31662|...  Success
#
#   Supplier_Invoice_Number    Supplier Company Currency_Reference  \
# 0     185385862-185317575  SUP-010419   CO102                USD
#
#   Default_Tax_Option_Reference  Line Invoice_Date Invoice_Received_Date  \
# 0                 CALC_TAX_DUE   NaN   2026-05-05            2026-05-05
#
#    Control_Amount_Total Payment_Terms_Reference Memo Spend_Category_Reference  \
# 0                  60.0                  NET_15  NaN                      NaN
#
#   Tax_Applicability_Reference Tax_Code_Reference  Extended_Amount  Project  \
# 0                         NaN                NaN              NaN      NaN
#
#   Cost_Center  Line_of_Business  Trust User_ID Message
# 0         NaN               NaN    NaN     NaN     NaN

# %%
ap_filter = Ap_combine_data['Status'] == 'Success'

Ap_combine_success_data = Ap_combine_data[ap_filter]

Ap_combine_success_data.head(2)
# Out:
#                                         Batch_Number   Status  \
# 0  Symphoni_PR_Invoice_GBR_2026-05-07.xlsx|31662|...  Success
# 1  Symphoni_PR_Invoice_GBR_2026-05-07.xlsx|31662|...  Success
#
#   Supplier_Invoice_Number    Supplier Company Currency_Reference  \
# 0     185385862-185317575  SUP-010419   CO102                USD
# 1     185385735-185317970      331842   CO120                USD
#
#   Default_Tax_Option_Reference  Line Invoice_Date Invoice_Received_Date  \
# 0                 CALC_TAX_DUE   NaN   2026-05-05            2026-05-05
# 1                 CALC_TAX_DUE   NaN   2026-05-06            2026-05-06
#
#    Control_Amount_Total Payment_Terms_Reference Memo Spend_Category_Reference  \
# 0                  60.0                  NET_15  NaN                      NaN
# 1                  90.0                  NET_15  NaN                      NaN
#
#   Tax_Applicability_Reference Tax_Code_Reference  Extended_Amount  Project  \
# ...

# %%
unmatched_records = combine_filtered[~combine_filtered['concat'].isin(Ap_combine_success_data['Supplier_Invoice_Number'])] #remove ~ to get matched records
print(f"Unmatched records : {len(unmatched_records)}")
unmatched_records.head(2)
# Out:
# Unmatched records : 97
# 0 Provider ID   Provider Name                   Employment Type Supplier ID  \
# 0      498335  Garnham Steven  Contractor (Affiliated Provider)      419386
# 1      498335  Garnham Steven                               NaN      419386
#
# 0 Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 0       NaN                         No  UNITED STATES OF AMERICA
# 1       NaN                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                           Org Name  \
# 0             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
# 1             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
#
# 0         Renewal Date Max hours for contract period Provider Email Type  \
# 0  2025-10-01 00:00:00                           NaN                 NaN
# 1  2025-10-01 00:00:00                           NaN                 NaN
#
# 0 Model Number                Fee Type    Case ID Activity ID  \
# ...

# %%
Ap_combine_data_prev = pd.read_excel(Prev_WD_Files_path,sheet_name= 'WD')
Ap_combine_data_prev.head(2)
# Out:
#                                         Batch_Number   Status  \
# 0  Symphoni_PR_Invoice_USA_2026-04-30.xlsx|31511|...  Success
# 1  Symphoni_PR_Invoice_USA_2026-04-30.xlsx|31511|...  Success
#
#   Supplier_Invoice_Number    Supplier Company Currency_Reference  \
# 0     185351426-185315816      129754   CO102                USD
# 1     185351964-185315695  SUP-015241   CO120                USD
#
#   Default_Tax_Option_Reference  Line Invoice_Date Invoice_Received_Date  \
# 0                 CALC_TAX_DUE   NaN   2026-04-29            2026-04-29
# 1                 CALC_TAX_DUE   NaN   2026-04-28            2026-04-28
#
#    Control_Amount_Total Payment_Terms_Reference
# 0                 200.0                  NET_15
# 1                  80.0                  NET_15

# %%
New_unmatched_records = unmatched_records[~unmatched_records['concat'].isin(Ap_combine_data_prev['Supplier_Invoice_Number'])] #remove ~ to get matched records
print(f"Unmatched records : {len(New_unmatched_records)}")
New_unmatched_records.head(2)
# Out:
# Unmatched records : 48
# 0 Provider ID          Provider Name                   Employment Type  \
# 1      498335         Garnham Steven                               NaN
# 2        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
#
# 0 Supplier ID  Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 1      419386        NaN                         No  UNITED STATES OF AMERICA
# 2      341143  184000746                        Yes                    CANADA
#
# 0 Provider  Province/State     Org ID                           Org Name  \
# 1             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
# 2                   QUEBEC  184039965                  MEDIATEK USA INC.
#
# 0         Renewal Date Max hours for contract period Provider Email Type  \
# 1  2025-10-01 00:00:00                           NaN                 NaN
# 2  2026-01-01 00:00:00                           NaN                 NaN
#
# ...

# %%
print(f"Count of total payable zero is : {len(New_unmatched_records[(New_unmatched_records['Total Payable']==0) & (New_unmatched_records['Total Invoice']==0 )])}")
New_unmatched_records[(New_unmatched_records['Total Payable']==0) & (New_unmatched_records['Total Invoice']==0 )]
# Out:
# Count of total payable zero is : 23
# 0   Provider ID                           Provider Name  \
# 14    184000902                             Help Better
# 16    184000902                             Help Better
# 17    184000902                             Help Better
# 18    184000902                             Help Better
# 22        26626  Dummy Provider – Canada  Cross Border
# 56    184000902                             Help Better
# 57    184000902                             Help Better
# 58    184000902                             Help Better
# 59    184000902                             Help Better
# 60    184000902                             Help Better
# 61    184000902                             Help Better
# 62    184000902                             Help Better
# 63    184000902                             Help Better
# 64    184000902                             Help Better
# 65    184000902                             Help Better
# ...

# %%
print(f"Total records are : {len(New_unmatched_records[(New_unmatched_records['Total Payable']!=0) | (New_unmatched_records['Total Invoice']!=0 )])}")
New_unmatched_records_nonzero = New_unmatched_records[(New_unmatched_records['Total Payable']!=0) | (New_unmatched_records['Total Invoice']!=0 )]
New_unmatched_records_nonzero.head()
# Out:
# Total records are : 25
# 0 Provider ID          Provider Name                   Employment Type  \
# 1      498335         Garnham Steven                               NaN
# 2        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
#
# 0 Supplier ID  Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 1      419386        NaN                         No  UNITED STATES OF AMERICA
# 2      341143  184000746                        Yes                    CANADA
# 3      341143  184000746                        Yes                    CANADA
# 4      341143  184000746                        Yes                    CANADA
# 5      341143  184000746                        Yes                    CANADA
#
# ...

# %%
New_unmatched_records_nonzero.shape
# Out:
# (25, 66)

# %%
New_unmatched_records_nonzero[New_unmatched_records_nonzero.duplicated(subset=['concat'], keep=False)]
#Contrast with other keep values:

#keep='first' (default): Marks duplicates as True except for the first occurrence.
#keep='last': Marks duplicates as True except for the last occurrence.
#keep = False : It shows all occurrences of duplicates, including the first appearance.
# Out:
# 0  Provider ID          Provider Name                   Employment Type  \
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 7         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 12        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 13        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# ...

# %%
#unmatched_records_nonzero = unmatched_records_nonzero.drop(7)
#unmatched_records_nonzero = unmatched_records_nonzero.drop(8)
#unmatched_records_nonzero = unmatched_records_nonzero.drop(70)
#unmatched_records_nonzero = unmatched_records_nonzero.drop(71)

# %%
print(len(New_unmatched_records_nonzero[New_unmatched_records_nonzero.duplicated(subset=['concat'], keep=False)]))
New_unmatched_records_nonzero[New_unmatched_records_nonzero.duplicated(subset=['concat'], keep=False)]
# Out:
# 18
# 0  Provider ID          Provider Name                   Employment Type  \
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 7         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 12        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 13        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# ...

# %%
New_unmatched_records_nonzero.drop_duplicates(subset=['concat'], inplace= True)
# Out:
# C:\Users\gaurav.trivedi\AppData\Local\Temp\ipykernel_22784\3356335658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_unmatched_records_nonzero.drop_duplicates(subset=['concat'], inplace= True)

# %%
#unmatched_records_nonzero.loc[29,'Total Payable'] #To check individual data

# %%
#unmatched_records_nonzero.loc[16,'Total Payable'] = 250

# %%
#unmatched_records_nonzero.loc[16,'Total Invoice'] = 250

# %%
#unmatched_records_nonzero = unmatched_records_nonzero.drop(17)

# %%
#unmatched_records_nonzero.loc[29,'Total Payable'] #Validated

# %%
#unmatched_records_nonzero.loc[[16]] #Validated

# %%
New_unmatched_records_nonzero.shape
# Out:
# (15, 66)

# %%
New_unmatched_records_nonzero[New_unmatched_records_nonzero.duplicated(subset=['Invoice ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Provider ID, Provider Name, Employment Type, Supplier ID, Vendor ID, Pay Vendor Directly (Y/N)?, Provider Country, Provider  Province/State, Org ID, Org Name, Renewal Date, Max hours for contract period, Provider Email Type, Model Number, Fee Type, Case ID, Activity ID, Activity Opened Date, Activity Status, Service Code, Modality, Invoice ID, Invoice Status, Invoice Approval Date, Approver Name, Provider Invoice Number, Invoice Created Date, Created by, Export Date, Regular Rate Fee, Regular Rate Type, Regular Rate Billable
# Hours, Regular Rate Non-Billable
# Hours, No Show
# Fee, No Show
# Type, No Show Billable
# Hours, No Show Non-Billable
# Hours, Case Management Fee, Case Management Type, Case Management Billble Hours, Case Management Non-Billble Hours, Special Rate Fee, Special Rate Type, Special Rate Billable
# Hours, Special Rate Non-Billable
# Hours, Other
# Billable
# Hours, Other
# Non-Billable
# Hours, Staff
# Billable
#  Hours, Staff
# ...

# %%
New_unmatched_records_nonzero.columns
# Out:
# Index(['Provider ID', 'Provider Name', 'Employment Type', 'Supplier ID',
#        'Vendor ID', 'Pay Vendor Directly (Y/N)?', 'Provider Country',
#        'Provider  Province/State', 'Org ID', 'Org Name', 'Renewal Date',
#        'Max hours for contract period', 'Provider Email Type', 'Model Number',
#        'Fee Type', 'Case ID', 'Activity ID', 'Activity Opened Date',
#        'Activity Status', 'Service Code', 'Modality', 'Invoice ID',
#        'Invoice Status', 'Invoice Approval Date', 'Approver Name',
#        'Provider Invoice Number', 'Invoice Created Date', 'Created by',
#        'Export Date', 'Regular Rate Fee', 'Regular Rate Type',
#        'Regular Rate Billable \nHours', 'Regular Rate Non-Billable \nHours',
#        'No Show \nFee', 'No Show \nType', 'No Show Billable\nHours',
#        'No Show Non-Billable\nHours', 'Case Management Fee',
#        'Case Management Type', 'Case Management Billble Hours',
#        'Case Management Non-Billble Hours', 'Special Rate Fee',
# ...

# %%
New_data = New_unmatched_records_nonzero.drop(['Regular Rate Billable \nHours', 'Regular Rate Non-Billable \nHours',
       'No Show \nFee', 'No Show \nType', 'No Show Billable\nHours',
       'No Show Non-Billable\nHours', 'Case Management Fee',
       'Case Management Type', 'Case Management Billble Hours',
       'Case Management Non-Billble Hours', 'Special Rate Fee',
       'Special Rate Type', 'Special Rate Billable\nHours',
       'Special Rate Non-Billable\nHours', 'Other \nBillable\nHours',
       'Other \nNon-Billable\nHours', 'Staff\nBillable\n Hours',
       'Staff\nNon-Billable\n Hours', 'Total \nBillable\nHours',
       'Total \nNon-Billable\nHours', 'Total \nPayable\nHours',
       'Total \nNon-Payable\nHours', 'Expenses  non Payable'], axis=1)

# %%
New_data.shape
# Out:
# (15, 43)

# %%
## now next step is check and if

# %%
New_data.columns
# Out:
# Index(['Provider ID', 'Provider Name', 'Employment Type', 'Supplier ID',
#        'Vendor ID', 'Pay Vendor Directly (Y/N)?', 'Provider Country',
#        'Provider  Province/State', 'Org ID', 'Org Name', 'Renewal Date',
#        'Max hours for contract period', 'Provider Email Type', 'Model Number',
#        'Fee Type', 'Case ID', 'Activity ID', 'Activity Opened Date',
#        'Activity Status', 'Service Code', 'Modality', 'Invoice ID',
#        'Invoice Status', 'Invoice Approval Date', 'Approver Name',
#        'Provider Invoice Number', 'Invoice Created Date', 'Created by',
#        'Export Date', 'Regular Rate Fee', 'Regular Rate Type', 'Total Hours',
#        'Taxes', 'Total Invoice', 'Currency', 'Expenses Payable',
#        'Total Payable', 'Comment', 'Source', 'Taxes: Province/State',
#        'Tax Type', 'Tax Account Number', 'concat'],
#       dtype='object', name=0)

# %%
New_data.head(1)
# Out:
# 0 Provider ID   Provider Name Employment Type Supplier ID Vendor ID  \
# 1      498335  Garnham Steven             NaN      419386       NaN
#
# 0 Pay Vendor Directly (Y/N)?          Provider Country  \
# 1                         No  UNITED STATES OF AMERICA
#
# 0 Provider  Province/State     Org ID                           Org Name  \
# 1             PENNSYLVANIA  184053652  Canadian Pacific Kansas City - US
#
# 0         Renewal Date Max hours for contract period Provider Email Type  \
# 1  2025-10-01 00:00:00                           NaN                 NaN
#
# 0 Model Number                Fee Type    Case ID Activity ID  \
# 1            1  Per Employee Per Month  184910423   185357531
#
# 0        Activity Opened Date Activity Status Service Code          Modality  \
# 1  2026-03-31 16:34:09.007000          Closed           SA  Tele-Counselling
#
# 0 Invoice ID Invoice Status Invoice Approval Date Approver Name  \
# ...

# %%
New_data['check'] = (New_data['Regular Rate Fee'] * New_data['Total Hours']) == New_data['Total Payable']

# %%
pd.set_option('display.max_rows',None)
New_data = New_data.reset_index(drop=True)
New_data
# Out:
# 0  Provider ID          Provider Name                   Employment Type  \
# 0       498335         Garnham Steven                               NaN
# 1         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 7         4032           Continuum R3                               NaN
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# ...

# %%
# New_data[New_data['check'] == False]

# %%
# New_data.loc[95,'Total Payable'] = 508.50 #Replacing it with correct amount
# New_data.loc[96,'Total Payable'] = 508.50 #Replacing it with correct amount
# New_data.loc[7,'Total Payable'] = 508.50 #Replacing it with correct amount
# New_data.loc[7,'Total Invoice'] = 450 #Replacing it with correct amount

# %%
New_data[New_data['Provider ID'] == 1542]
# Out:
# 0  Provider ID          Provider Name                   Employment Type  \
# 1         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
#
# 0  Supplier ID  Vendor ID Pay Vendor Directly (Y/N)? Provider Country  \
# 1       341143  184000746                        Yes           CANADA
# ...

# %%
New_data['Tax code'] = New_data.apply(
    lambda row: 'ONA' if row['Provider ID'] == 1542 else 'EXEMPT',
    axis=1
)
#.apply method is slower for large dataset

# %%
# New_data['tax'] = np.where(
#     New_data['Provider ID'] == 1542,
#     'ONA',
#     'EXEMPT'
# ) #This is for large dataset its faster

# %%
New_data.head()
# Out:
# 0 Provider ID          Provider Name                   Employment Type  \
# 0      498335         Garnham Steven                               NaN
# 1        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 2        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
#
# 0 Supplier ID  Vendor ID Pay Vendor Directly (Y/N)?          Provider Country  \
# 0      419386        NaN                         No  UNITED STATES OF AMERICA
# 1      341143  184000746                        Yes                    CANADA
# 2      341143  184000746                        Yes                    CANADA
# 3      341143  184000746                        Yes                    CANADA
# 4      341143  184000746                        Yes                    CANADA
#
# ...

# %%
def assign_cost_centre(row):
    if row['Service Code'] == 'WRP' and row['Provider  Province/State'] == 'CALIFORNIA':
        return 'C4199'
    elif row['Service Code'] == 'SA' and row['Provider  Province/State'] == 'CALIFORNIA':
        return 'C4199'
    elif row['Service Code'] == 'ST2' and row['Provider  Province/State'] == 'CALIFORNIA':
        return 'C4199'
    elif row['Service Code'] == 'ST' and row['Provider  Province/State'] == 'CALIFORNIA':
        return 'C4199'
    elif row['Service Code'] == 'AR' and row['Provider  Province/State'] == 'CALIFORNIA':
        return 'C4199'
    elif row['Service Code'] == 'WRP':
        return 'C4103'
    elif row['Service Code'] == 'SA':
        return 'C4103'
    elif row['Service Code'] == 'ST2':
        return 'C4156'
    elif row['Service Code'] == 'ST':
        return 'C4156'
    elif row['Service Code'] == 'AR':
        return 'C4156'
    elif row['Service Code'] == 'Knox Keene':
        return 'C4199'
    elif row['Service Code'] == 'SM':
        return 'C4305'
    elif row['Service Code'] == 'WSH':
        return 'C4305'
    elif row['Service Code'] == 'HLC':
        return 'C4507'
    elif row['Service Code'] == 'SC':
        return 'C4507'
    elif row['Service Code'] == 'SL':
        return 'C4507'
    elif row['Service Code'] == 'LC':
        return 'C4507'
    elif row['Service Code'] == 'DBR':
        return 'C4120'
    else :
        return 'C4120'

New_data['Cost Centre'] = New_data.apply(assign_cost_centre,axis = 1)

# %%
New_data
# Out:
# 0  Provider ID          Provider Name                   Employment Type  \
# 0       498335         Garnham Steven                               NaN
# 1         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 7         4032           Continuum R3                               NaN
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# ...

# %%
# New_data.loc[[9]]

# %%
#Add final columns

# %%
New_data = New_data.reset_index(drop=True)
New_data
# Out:
# 0  Provider ID          Provider Name                   Employment Type  \
# 0       498335         Garnham Steven                               NaN
# 1         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 2         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 3         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 4         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 5         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 6         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 7         4032           Continuum R3                               NaN
# 8         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 9         1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 10        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# 11        1542  Nutrition at Work NDC  Contractor (Affiliated Provider)
# ...

# %%
New_data['Total Payable'].sum()
# Out:
# 2137.5

# %%
New_data.columns
# Out:
# Index(['Provider ID', 'Provider Name', 'Employment Type', 'Supplier ID',
#        'Vendor ID', 'Pay Vendor Directly (Y/N)?', 'Provider Country',
#        'Provider  Province/State', 'Org ID', 'Org Name', 'Renewal Date',
#        'Max hours for contract period', 'Provider Email Type', 'Model Number',
#        'Fee Type', 'Case ID', 'Activity ID', 'Activity Opened Date',
#        'Activity Status', 'Service Code', 'Modality', 'Invoice ID',
#        'Invoice Status', 'Invoice Approval Date', 'Approver Name',
#        'Provider Invoice Number', 'Invoice Created Date', 'Created by',
#        'Export Date', 'Regular Rate Fee', 'Regular Rate Type', 'Total Hours',
#        'Taxes', 'Total Invoice', 'Currency', 'Expenses Payable',
#        'Total Payable', 'Comment', 'Source', 'Taxes: Province/State',
#        'Tax Type', 'Tax Account Number', 'concat', 'check', 'Tax code',
#        'Cost Centre'],
#       dtype='object', name=0)

# %%
New_data[['Provider ID', 'Provider Name','Supplier ID','Vendor ID', 'Pay Vendor Directly (Y/N)?','Provider  Province/State',
          'Activity ID','Service Code','Cost Centre','Invoice ID','Provider Invoice Number','Invoice Created Date','Taxes','Total Invoice',
         'Currency','Expenses Payable','Total Payable','Comment','Tax code']]
# Out:
# 0  Provider ID          Provider Name Supplier ID  Vendor ID  \
# 0       498335         Garnham Steven      419386        NaN
# 1         1542  Nutrition at Work NDC      341143  184000746
# 2         1542  Nutrition at Work NDC      341143  184000746
# 3         1542  Nutrition at Work NDC      341143  184000746
# 4         1542  Nutrition at Work NDC      341143  184000746
# 5         1542  Nutrition at Work NDC      341143  184000746
# 6         1542  Nutrition at Work NDC      341143  184000746
# 7         4032           Continuum R3      236307        409
# 8         1542  Nutrition at Work NDC      341143  184000746
# 9         1542  Nutrition at Work NDC      341143  184000746
# 10        1542  Nutrition at Work NDC      341143  184000746
# 11        1542  Nutrition at Work NDC      341143  184000746
# 12       14073        Nichols Abayomi      226682        NaN
# 13       14073        Nichols Abayomi      226682        NaN
# ...

# %%
Final_output = New_data[['Provider ID', 'Provider Name','Supplier ID','Vendor ID', 'Pay Vendor Directly (Y/N)?','Provider  Province/State',
          'Activity ID','Service Code','Cost Centre','Invoice ID','Provider Invoice Number','Invoice Created Date','Taxes','Total Invoice',
         'Currency','Expenses Payable','Total Payable','Comment','Tax code','check']]
Final_output.shape
# Out:
# (15, 20)

# %%
Final_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Provider ID                 15 non-null     object
#  1   Provider Name               15 non-null     object
#  2   Supplier ID                 15 non-null     object
#  3   Vendor ID                   11 non-null     object
#  4   Pay Vendor Directly (Y/N)?  15 non-null     object
#  5   Provider  Province/State    15 non-null     object
#  6   Activity ID                 15 non-null     object
#  7   Service Code                15 non-null     object
#  8   Cost Centre                 15 non-null     object
#  9   Invoice ID                  15 non-null     object
#  10  Provider Invoice Number     11 non-null     object
#  11  Invoice Created Date        15 non-null     datetime64[ns]
#  12  Taxes                       15 non-null     object
# ...

# %%
#Final_output['Invoice Created Date'] = pd.to_datetime(Final_output['Invoice Created Date'], errors='coerce')
Final_output['Invoice Created Date'] = Final_output['Invoice Created Date'].dt.date
# Out:
# C:\Users\gaurav.trivedi\AppData\Local\Temp\ipykernel_22784\3399996020.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_output['Invoice Created Date'] = Final_output['Invoice Created Date'].dt.date

# %%
print(Final_output.dtypes)
# Out:
# 0
# Provider ID                   object
# Provider Name                 object
# Supplier ID                   object
# Vendor ID                     object
# Pay Vendor Directly (Y/N)?    object
# Provider  Province/State      object
# Activity ID                   object
# Service Code                  object
# Cost Centre                   object
# Invoice ID                    object
# Provider Invoice Number       object
# Invoice Created Date          object
# Taxes                         object
# Total Invoice                 object
# Currency                      object
# Expenses Payable              object
# Total Payable                 object
# Comment                       object
# Tax code                      object
# check                           bool
# dtype: object

# %%
# Output_path = 'C:\\Gaurav\\Practice\\New folder\\Output\\Final.xlsx'
# Final_output.to_excel(Output_path,sheet_name='Not in WD-FNL',index = False)

# %%
df1 = filtered_data1
df2 = combine_filtered  
df3 = Ap_combine_success_data
df4 = Ap_combine_data_prev
df5 = unmatched_records
df6 = New_unmatched_records
df7 = New_unmatched_records_nonzero
df8 = New_data
df9 = Final_output

# Create Excel writer object
with pd.ExcelWriter(Output_path, engine='openpyxl') as writer:
    df1.to_excel(writer, sheet_name='Filtered', index=False)
    df2.to_excel(writer, sheet_name='Combine_filtered', index=False)
    df3.to_excel(writer, sheet_name='WD', index=False)
    df4.to_excel(writer, sheet_name='WD-prev', index=False)
    df5.to_excel(writer, sheet_name='Not in WD', index=False)
    df6.to_excel(writer, sheet_name='Not in WD Final', index=False)
    df7.to_excel(writer, sheet_name='Not in WD Final working', index=False)
    df8.to_excel(writer, sheet_name='Final', index=False)
    df9.to_excel(writer, sheet_name='Final Sorted', index=False)

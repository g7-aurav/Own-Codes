# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\GAURAV\ExcelR\My Project\project 4 python\Amazon review on women dress\Women Dresses Reviews Dataset .csv")

# %%
data.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
data.shape
# Out:
# (23486, 11)

# %%
data.size
# Out:
# 258346

# %%
data.dtypes
# Out:
# s.no                     int64
# age                      int64
# division_name           object
# department_name         object
# class_name              object
# clothing_id              int64
# title                   object
# review_text             object
# alike_feedback_count     int64
# rating                   int64
# recommend_index          int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   s.no                  23486 non-null  int64
#  1   age                   23486 non-null  int64
#  2   division_name         23472 non-null  object
#  3   department_name       23472 non-null  object
#  4   class_name            23472 non-null  object
#  5   clothing_id           23486 non-null  int64
#  6   title                 19676 non-null  object
#  7   review_text           22641 non-null  object
#  8   alike_feedback_count  23486 non-null  int64
#  9   rating                23486 non-null  int64
#  10  recommend_index       23486 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [s.no, age, division_name, department_name, class_name, clothing_id, title, review_text, alike_feedback_count, rating, recommend_index ]
# Index: []

# %%
data.isnull().sum()
# Out:
# s.no                       0
# age                        0
# division_name             14
# department_name           14
# class_name                14
# clothing_id                0
# title                   3810
# review_text              845
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna(how='any',inplace=True)

# %%
data.isnull().sum()
# Out:
# s.no                    0
# age                     0
# division_name           0
# department_name         0
# class_name              0
# clothing_id             0
# title                   0
# review_text             0
# alike_feedback_count    0
# rating                  0
# recommend_index         0
# dtype: int64

# %%
data.shape
# Out:
# (19662, 11)

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
data['division_name'].unique()
# Out:
# array(['General', 'General Petite', 'Initmates'], dtype=object)

# %%
data['division_name'].value_counts()
# Out:
# General           11664
# General Petite     6778
# Initmates          1220
# Name: division_name, dtype: int64

# %%
data['class_name'].unique()
# Out:
# array(['Jeans', 'Blouses', 'Skirts', 'Pants', 'Swim', 'Sweaters', 'Knits',
#        'Fine gauge', 'Dresses', 'Shorts', 'Jackets', 'Outerwear',
#        'Lounge', 'Intimates', 'Legwear', 'Trend', 'Sleep', 'Layering',
#        'Casual bottoms', 'Chemises'], dtype=object)

# %%
data['class_name'].value_counts()
# Out:
# Dresses           5371
# Knits             3981
# Blouses           2587
# Sweaters          1218
# Pants             1157
# Jeans              970
# Fine gauge         927
# Skirts             796
# Jackets            598
# Lounge             574
# Swim               293
# Outerwear          281
# Shorts             260
# Sleep              174
# Legwear            131
# Intimates          120
# Layering           115
# Trend              107
# Casual bottoms       1
# Chemises             1
# Name: class_name, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data['class_name'])
plt.xticks(rotation=90)
plt.figure(figsize=(10,8))
# Out:
# C:\Users\91968\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
data['department_name'].unique()
# Out:
# array(['Bottoms', 'Tops', 'Intimate', 'Dresses', 'Jackets', 'Trend'],
#       dtype=object)

# %%
data['department_name'].value_counts()
# Out:
# Tops        8713
# Dresses     5371
# Bottoms     3184
# Intimate    1408
# Jackets      879
# Trend        107
# Name: department_name, dtype: int64

# %%
sns.countplot(data['department_name'])
plt.xticks(rotation=90)
# Out:
# C:\Users\91968\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Bottoms'),
#   Text(1, 0, 'Tops'),
#   Text(2, 0, 'Intimate'),
#   Text(3, 0, 'Dresses'),
#   Text(4, 0, 'Jackets'),
#   Text(5, 0, 'Trend')])

# %%
data.rating.unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
data['rating'].value_counts()
# Out:
# 5    10858
# 4     4289
# 3     2464
# 2     1360
# 1      691
# Name: rating, dtype: int64

# %%
data['age'].value_counts()
# Out:
# 39    1103
# 35     728
# 34     669
# 36     664
# 38     658
#       ...
# 81       2
# 94       1
# 92       1
# 87       1
# 99       1
# Name: age, Length: 77, dtype: int64

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
data['clothing_id'].value_counts().head(10)
# Out:
# 1078    871
# 862     658
# 1094    651
# 1081    487
# 829     452
# 872     450
# 1110    419
# 868     370
# 895     336
# 867     291
# Name: clothing_id, dtype: int64

# %%
plt.figure(figsize=(25,15))
chains=data['clothing_id'].value_counts()[:20]
sns.barplot(y=chains,x=chains.index,palette='Set1')
plt.title("Highest city sale ",size=20,pad=20)
plt.xlabel("count",size=15)
plt.xticks(fontsize=12,fontweight='bold')
plt.yticks(fontsize=15,fontweight='bold');

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
data[data['clothing_id']==1078]
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 17        17   50  General Petite         Dresses    Dresses         1078
# 26        26   49  General Petite         Dresses    Dresses         1078
# 93        93   55         General         Dresses    Dresses         1078
# 112      112   31         General         Dresses    Dresses         1078
# 121      121   51         General         Dresses    Dresses         1078
# ...      ...  ...             ...             ...        ...          ...
# 23296  23296   36         General         Dresses    Dresses         1078
# 23336  23336   41  General Petite         Dresses    Dresses         1078
# 23351  23351   29         General         Dresses    Dresses         1078
# 23371  23371   32         General         Dresses    Dresses         1078
# 23400  23400   39         General         Dresses    Dresses         1078
#
#                                                 title  \
# ...

# %%
data[data['clothing_id']==862].shape
# Out:
# (658, 11)

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
plt.figure(figsize=(25,15))
chains=data['age'].value_counts()
sns.barplot(y=chains,x=chains.index,palette='Set1')
plt.title("Highest city sale ",size=20,pad=20)
plt.xlabel("Age",size=15)
plt.xticks(fontsize=12,fontweight='bold')
plt.yticks(fontsize=15,fontweight='bold');

# %%
data['alike_feedback_count'].unique()
# Out:
# array([  0,  12,   3,   4,   2,   5,  22,  13,   1,   7,   6,   9,  11,
#         23,  17,   8,  20,  31,  10,  14,  16,  43,  18,  21,  65,  28,
#         32,  15,  29,  24,  26,  30,  19,  41,  27,  53,  61,  38,  45,
#         36,  42,  25, 122,  98,  34,  93,  35,  58,  46,  81,  33,  87,
#         39,  89,  51,  54,  37,  50,  84,  44,  55,  59,  77,  47,  57,
#         99,  68,  66,  95,  78,  52,  82,  49,  40,  94, 108,  69,  64,
#         48], dtype=int64)

# %%
data[data['alike_feedback_count']==122]
# Out:
#       s.no  age division_name department_name class_name  clothing_id  \
# 3329  3329   34       General         Dresses    Dresses         1092
#
#                                      title  \
# 3329  Beware if you're fuller in the chest
#
#                                             review_text  alike_feedback_count  \
# 3329  I loved the lace detailing all over this dress...                   122
#
#       rating  recommend_index
# 3329       3                 1

# %%
data.head(2)
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
#
#                   title                                        review_text  \
# 0  Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1    Lovely and unique!  As is true of a bunch of the fall clothing pho...
#
#    alike_feedback_count  rating  recommend_index
# 0                     0       5                 1
# 1                    12       5                 1

# %%
plt.figure(figsize=(15,6))
sns.countplot(x= "department_name", hue="division_name", data=data)
plt.title('Relation Between Body Injury and PED Role')
plt.xticks(rotation=90)
plt.show()
